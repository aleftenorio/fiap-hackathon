# %%
import pandas as pd

# %%
df = pd.read_csv('part-00000.csv')

df.head()
# Out:
#                  encrypted_cnpj  \
# 0  711e100ff690bde75f1d51c6e120
# 1  4a098a906a2665ddb6ca051beed9
# 2  1e1ac070864ab84b577827593eea
# 3  fb1cb37dd9253ea2cd62ea7873e1
# 4  4376025158df6f2139ec8d03f795
#
#                                  encrypted_5_zipcode  \
# 0  3162373836343536353430623937303763373938366431...
# 1  3530366161376161303533636633333935636239663964...
# 2  3938623435356438366362666138373130643936636265...
# 3  3031623865306336323665636530313030326239386636...
# 4  6335616165626335316433323039616335386334353133...
#
#                                     encrypted_domain       cnae  cheque  \
# 0  6139646137356433363237396637323937336161383832...        NaN     NaN
# 1  6139646137356433363237396637323937336161383832...        NaN     0.0
# 2  6139646137356433363237396637323937336161383832...        NaN     0.0
# 3  6139646137356433363237396637323937336161383832...  4612500.0     1.0
# 4  6139646137356433363237396637323937336161383832...        NaN     1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Data columns (total 11 columns):
# encrypted_cnpj         1630 non-null object
# encrypted_5_zipcode    1626 non-null object
# encrypted_domain       1630 non-null object
# cnae                   283 non-null float64
# cheque                 1490 non-null float64
# crediario              999 non-null float64
# credito                1490 non-null float64
# debito                 1490 non-null float64
# deposito               1547 non-null float64
# dinheiro               1490 non-null float64
# transferencia          1547 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 140.2+ KB

# %%
df.describe()
# Out:
#                cnae       cheque   crediario      credito       debito  \
# count  2.830000e+02  1490.000000  999.000000  1490.000000  1490.000000
# mean   4.871866e+06     0.017519    0.052059     0.164875     0.244173
# std    5.225976e+05     0.110263    0.222242     0.240024     0.318667
# min    4.520004e+06     0.000000    0.000000     0.000000     0.000000
# 25%    4.729699e+06     0.000000    0.000000     0.000000     0.000000
# 50%    4.732600e+06     0.000000    0.000000     0.000000     0.000000
# 75%    4.772500e+06     0.000000    0.000000     0.307244     0.570452
# max    9.511800e+06     1.000000    1.000000     1.000000     1.000000
#
#           deposito     dinheiro  transferencia
# count  1547.000000  1490.000000   1.547000e+03
# mean      0.000020     0.170724   3.835251e-08
# std       0.000440     0.351275   1.508478e-06
# min       0.000000     0.000000   0.000000e+00
# 25%       0.000000     0.000000   0.000000e+00
# ...
